# %% [markdown]
# ## Fig 3: reinterpretation effect
#
# Plots the LMER outputs from `005._subject_by_node_Viewing1_Viewing2_network_reinterpretation.Rmd`
# as (1) a parcel-wise cortical surface map and (2) a 17-network effect distribution.

# %%
import os
import sys

import numpy as np
import pandas as pd
import matplotlib as mpl

from brainspace.datasets import load_parcellation
from neuromaps.datasets import fetch_fslr

sys.path.append('../utils/')
from plotting_brains_surfplot import map_values_to_atlas, Plot
from plotting_network_plots import (
    compare_network_effects,
    plot_17N_effect_distribution_horizontal,
)

mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = ['Helvetica Neue']
mpl.rcParams['font.size'] = 14

MODEL_OUTPUTS = 'model_outputs'
RESULTS_DIR = '../../results/reinterpretation_plots/'

# %%
surfaces = fetch_fslr()
lh, rh = surfaces['inflated']
atlas_surf = load_parcellation('schaefer', 100, join=True)

# %% [markdown]
# ### Loading in the data from the R models to plot

# %%
all_sub = pd.read_csv(os.path.join(
    MODEL_OUTPUTS, 'across_node_estimate_p_reinterpretation_neural_shift_poly_semantic_distance_3__reinterpretation.csv'))
network_values_17N = pd.read_csv(os.path.join(MODEL_OUTPUTS,'across_network_estimate_p_reinterpretation_neural_shift_poly_semantic_distance_3__17N.csv'))

column = 'neural_shift_poly_semantic_distance_3_1' #going to extract the linear fit one!
all_sub.head()
# Out:
#    node  _Intercept__estimate  _Intercept__p_value  neural_shift_estimate  \
# 0     1              0.555492         1.291199e-54              -0.005826
# 1     2              0.524819         1.338760e-49               0.029270
# 2     3              0.531686         2.282581e-54               0.020259
# 3     4              0.543393         2.452497e-54               0.006138
# 4     5              0.547576         1.659827e-54               0.001432
#
#    neural_shift_p_value  poly_semantic_distance_3_1_estimate  \
# 0              0.811492                            -0.426077
# 1              0.027893                            -1.799816
# 2              0.276369                            -0.911775
# 3              0.693155                            -2.226678
# 4              0.930228                            -1.783998
#
#    poly_semantic_distance_3_1_p_value  poly_semantic_distance_3_2_estimate  \
# 0                            0.685173                             1.218049
# 1                            0.001190                             0.668778
# 2                            0.225240                             0.619086
# 3                            0.000562                             0.418033
# 4                            0.007284                             0.237596
#
#    poly_semantic_distance_3_2_p_value  poly_semantic_distance_3_3_estimate  \
# 0                            0.252288                             1.775230
# 1                            0.227908                             1.676426
# 2                            0.412007                             1.146124
# 3                            0.516690                             0.276010
# 4                            0.719693                             0.794524
#
#    poly_semantic_distance_3_3_p_value  \
# 0                            0.122624
# 1                            0.003484
# 2                            0.160100
# 3                            0.686024
# 4                            0.260229
#
#    neural_shift_poly_semantic_distance_3_1_estimate  \
# 0                                         -0.963041
# 1                                          0.513257
# 2                                         -0.559082
# 3                                          0.871114
# 4                                          0.428483
#
#    neural_shift_poly_semantic_distance_3_1_p_value  \
# 0                                         0.331727
# 1                                         0.336151
# 2                                         0.473777
# 3                                         0.158078
# 4                                         0.521242
#
#    neural_shift_poly_semantic_distance_3_2_estimate  \
# 0                                         -0.576180
# 1                                         -0.060668
# 2                                         -0.006801
# 3                                          0.168648
# 4                                          0.399976
#
#    neural_shift_poly_semantic_distance_3_2_p_value  \
# 0                                         0.568402
# 1                                         0.911272
# 2                                         0.993146
# 3                                         0.791435
# 4                                         0.557928
#
#    neural_shift_poly_semantic_distance_3_3_estimate  \
# 0                                         -1.676944
# 1                                         -1.811150
# 2                                         -1.241993
# 3                                         -0.310589
# 4                                         -0.900439
#
#    neural_shift_poly_semantic_distance_3_3_p_value
# 0                                         0.116013
# 1                                         0.000773
# 2                                         0.137025
# 3                                         0.647211
# 4                                         0.212098

# %%
vals = all_sub[f'{column}_estimate'].to_numpy()
lim = np.max(np.abs(vals))

p = Plot(lh, rh, views=['lateral', 'medial'])
p.add_layer(map_values_to_atlas(atlas_surf, vals), cbar=True, cmap='RdBu_r',
            color_range=(-lim, lim), zero_transparent=False)

fig = p.build()
fig.savefig(os.path.join(RESULTS_DIR, f'surf_{column}.png'), dpi=300, transparent=True)

# %%
for plot_stars in (True, False): #plotitng it 2x to see the stats, but also I want it without to put in Illustrator
    plot_17N_effect_distribution_horizontal(
        compare_network_effects(network_values_17N, effects=[column]),
        all_sub,
        effect=column,
        ascending=True,
        show_bars=True,
        sort_by_effect=False,
        min_val_manual=-1,
        max_val_manual=4,
        x_offset=-.45,
        output_folder=RESULTS_DIR,
        plot_stars=plot_stars)
# Out:
# ['DAN-A' 'DAN-B' 'DMN-A' 'DMN-B' 'DMN-C' 'FPN-A' 'FPN-B' 'FPN-C' 'LimbicA'
#  'LimbicB' 'SomMotA' 'SomMotB' 'TempPar' 'VAN-A' 'VAN-B' 'VisCent'
#  'VisPeri']
# renamed them!
#
# Creating horizontal 17N distribution plot for: neural_shift_poly_semantic_distance_3_1
# Mode: Bar graph only
# Sorting by network family grouping
# === neural_shift_poly_semantic_distance_3_1 Summary (17N) ===
#
# VisCent:
#   Network Beta: 1.0249
#   q-value: 1.3127e-01
#   Node count: 7
#   Node mean: 0.5142
#   Node median: 0.5133
#   Node std: 0.3510
#   Node range: [0.0114, 1.0269]
#
# VisPeri:
#   Network Beta: -0.1449
#   q-value: 8.2217e-01
#   Node count: 6
#   Node mean: -0.0935
#   Node median: -0.0892
#   Node std: 0.2996
#   Node range: [-0.5591, 0.3805]
#
# SomMotA:
#   Network Beta: 0.7762
#   q-value: 1.8414e-01
#   Node count: 6
#   Node mean: 0.3255
#   Node median: 0.3118
#   Node std: 0.1186
#   Node range: [0.1982, 0.5221]
#
# SomMotB:
#   Network Beta: 0.9780
#   q-value: 1.2864e-01
#   Node count: 8
#   Node mean: 0.2556
#   Node median: 0.2092
#   Node std: 0.2438
#   Node range: [-0.0132, 0.7474]
#
# LimbicA:
#   Network Beta: 0.6159
#   q-value: 5.8704e-01
#   Node count: 3
#   Node mean: 0.2994
#   Node median: 0.3611
#   Node std: 0.2909
#   Node range: [-0.0174, 0.5544]
#
# LimbicB:
#   Network Beta: 2.5111
#   q-value: 6.1012e-02
#   Node count: 2
#   Node mean: 1.8090
#   Node median: 1.8090
#   Node std: 1.1708
#   Node range: [0.9811, 2.6369]
#
# TempPar:
#   Network Beta: 0.5308
#   q-value: 4.8831e-01
#   Node count: 4
#   Node mean: 0.2619
#   Node median: 0.3158
#   Node std: 0.5695
#   Node range: [-0.4816, 0.8976]
#
# DAN-A:
#   Network Beta: 0.6934
#   q-value: 3.2671e-01
#   Node count: 6
#   Node mean: 0.4008
#   Node median: 0.4426
#   Node std: 0.4426
#   Node range: [-0.1322, 0.9696]
#
# DAN-B:
#   Network Beta: 0.5942
#   q-value: 3.2671e-01
#   Node count: 7
#   Node mean: 0.2930
#   Node median: 0.3394
#   Node std: 0.1598
#   Node range: [-0.0157, 0.4949]
#
# VAN-A:
#   Network Beta: 1.2609
#   q-value: 1.1871e-01
#   Node count: 9
#   Node mean: 0.5024
#   Node median: 0.4648
#   Node std: 0.5605
#   Node range: [-0.3988, 1.2569]
#
# VAN-B:
#   Network Beta: 2.3828 **
#   q-value: 1.6338e-03
#   Node count: 5
#   Node mean: 1.1851
#   Node median: 1.0645
#   Node std: 0.3840
#   Node range: [0.7114, 1.7021]
#
# FPN-A:
#   Network Beta: 2.0322 **
#   q-value: 2.5328e-03
#   Node count: 6
#   Node mean: 0.9577
#   Node median: 0.9065
#   Node std: 0.5145
#   Node range: [0.4371, 1.8325]
#
# FPN-B:
#   Network Beta: 1.9654 **
#   q-value: 8.1611e-03
#   Node count: 5
#   Node mean: 0.9271
#   Node median: 0.9673
#   Node std: 0.5467
#   Node range: [0.3331, 1.6839]
#
# FPN-C:
#   Network Beta: 1.3276
#   q-value: 6.3729e-02
#   Node count: 5
#   Node mean: 0.7711
#   Node median: 0.7043
#   Node std: 0.4272
#   Node range: [0.2237, 1.3833]
#
# DMN-A:
#   Network Beta: 1.5756
#   q-value: 6.1012e-02
#   Node count: 7
#   Node mean: 0.6902
#   Node median: 0.7481
#   Node std: 0.2464
#   Node range: [0.3591, 1.0094]
#
# DMN-B:
#   Network Beta: 3.6638 ***
#   q-value: 3.1627e-07
#   Node count: 10
#   Node mean: 1.2662
#   Node median: 1.2568
#   Node std: 0.4380
#   Node range: [0.3341, 1.8464]
#
# DMN-C:
#   Network Beta: -0.6825
#   q-value: 4.3722e-01
#   Node count: 4
#   Node mean: -0.3742
#   Node median: -0.2623
#   Node std: 0.4104
#   Node range: [-0.9630, -0.0090]
#
# ✓ Horizontal 17N distribution plot saved to ../../results/reinterpretation_plots/
# ['DAN-A' 'DAN-B' 'DMN-A' 'DMN-B' 'DMN-C' 'FPN-A' 'FPN-B' 'FPN-C' 'LimbicA'
#  'LimbicB' 'SomMotA' 'SomMotB' 'TempPar' 'VAN-A' 'VAN-B' 'VisCent'
#  'VisPeri']
# renamed them!
#
# Creating horizontal 17N distribution plot for: neural_shift_poly_semantic_distance_3_1
# Mode: Bar graph only
# Sorting by network family grouping
# === neural_shift_poly_semantic_distance_3_1 Summary (17N) ===
#
# VisCent:
#   Network Beta: 1.0249
#   q-value: 1.3127e-01
#   Node count: 7
#   Node mean: 0.5142
#   Node median: 0.5133
#   Node std: 0.3510
#   Node range: [0.0114, 1.0269]
#
# VisPeri:
#   Network Beta: -0.1449
#   q-value: 8.2217e-01
#   Node count: 6
#   Node mean: -0.0935
#   Node median: -0.0892
#   Node std: 0.2996
#   Node range: [-0.5591, 0.3805]
#
# SomMotA:
#   Network Beta: 0.7762
#   q-value: 1.8414e-01
#   Node count: 6
#   Node mean: 0.3255
#   Node median: 0.3118
#   Node std: 0.1186
#   Node range: [0.1982, 0.5221]
#
# SomMotB:
#   Network Beta: 0.9780
#   q-value: 1.2864e-01
#   Node count: 8
#   Node mean: 0.2556
#   Node median: 0.2092
#   Node std: 0.2438
#   Node range: [-0.0132, 0.7474]
#
# LimbicA:
#   Network Beta: 0.6159
#   q-value: 5.8704e-01
#   Node count: 3
#   Node mean: 0.2994
#   Node median: 0.3611
#   Node std: 0.2909
#   Node range: [-0.0174, 0.5544]
#
# LimbicB:
#   Network Beta: 2.5111
#   q-value: 6.1012e-02
#   Node count: 2
#   Node mean: 1.8090
#   Node median: 1.8090
#   Node std: 1.1708
#   Node range: [0.9811, 2.6369]
#
# TempPar:
#   Network Beta: 0.5308
#   q-value: 4.8831e-01
#   Node count: 4
#   Node mean: 0.2619
#   Node median: 0.3158
#   Node std: 0.5695
#   Node range: [-0.4816, 0.8976]
#
# DAN-A:
#   Network Beta: 0.6934
#   q-value: 3.2671e-01
#   Node count: 6
#   Node mean: 0.4008
#   Node median: 0.4426
#   Node std: 0.4426
#   Node range: [-0.1322, 0.9696]
#
# DAN-B:
#   Network Beta: 0.5942
#   q-value: 3.2671e-01
#   Node count: 7
#   Node mean: 0.2930
#   Node median: 0.3394
#   Node std: 0.1598
#   Node range: [-0.0157, 0.4949]
#
# VAN-A:
#   Network Beta: 1.2609
#   q-value: 1.1871e-01
#   Node count: 9
#   Node mean: 0.5024
#   Node median: 0.4648
#   Node std: 0.5605
#   Node range: [-0.3988, 1.2569]
#
# VAN-B:
#   Network Beta: 2.3828 **
#   q-value: 1.6338e-03
#   Node count: 5
#   Node mean: 1.1851
#   Node median: 1.0645
#   Node std: 0.3840
#   Node range: [0.7114, 1.7021]
#
# FPN-A:
#   Network Beta: 2.0322 **
#   q-value: 2.5328e-03
#   Node count: 6
#   Node mean: 0.9577
#   Node median: 0.9065
#   Node std: 0.5145
#   Node range: [0.4371, 1.8325]
#
# FPN-B:
#   Network Beta: 1.9654 **
#   q-value: 8.1611e-03
#   Node count: 5
#   Node mean: 0.9271
#   Node median: 0.9673
#   Node std: 0.5467
#   Node range: [0.3331, 1.6839]
#
# FPN-C:
#   Network Beta: 1.3276
#   q-value: 6.3729e-02
#   Node count: 5
#   Node mean: 0.7711
#   Node median: 0.7043
#   Node std: 0.4272
#   Node range: [0.2237, 1.3833]
#
# DMN-A:
#   Network Beta: 1.5756
#   q-value: 6.1012e-02
#   Node count: 7
#   Node mean: 0.6902
#   Node median: 0.7481
#   Node std: 0.2464
#   Node range: [0.3591, 1.0094]
#
# DMN-B:
#   Network Beta: 3.6638 ***
#   q-value: 3.1627e-07
#   Node count: 10
#   Node mean: 1.2662
#   Node median: 1.2568
#   Node std: 0.4380
#   Node range: [0.3341, 1.8464]
#
# DMN-C:
#   Network Beta: -0.6825
#   q-value: 4.3722e-01
#   Node count: 4
#   Node mean: -0.3742
#   Node median: -0.2623
#   Node std: 0.4104
#   Node range: [-0.9630, -0.0090]
#
# ✓ Horizontal 17N distribution plot saved to ../../results/reinterpretation_plots/
